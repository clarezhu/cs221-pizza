# %%
import codecs
import numpy as np
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../new_data/train_all.csv")

# %% [markdown]
# ## Visualize requester account age

# %%
num_samples = len(df)
num_samples
# Out:
# 2760

# %%
df['requester_account_age_in_days_at_request'].head()
# Out:
# 0     512.0
# 1     693.0
# 2     776.0
# 3    2575.0
# 4    1512.0
# Name: requester_account_age_in_days_at_request, dtype: float64

# %%
plt.figure()
g = sns.catplot(x='requester_received_pizza', y='requester_account_age_in_days_at_request', data=df, alpha=0.3)

plt.xlabel('did the requester receive pizza?')
plt.title("New Pushshift Dataset")
plt.ylabel('requester account age at request (days)')
# Out:
# Text(-2.450000000000003, 0.5, 'requester account age at request (days)')

# %%
plt.figure()
colors = {1:'green', 0:'red'}

g = sns.swarmplot(x='requester_num_pizza_received_at_request', y='requester_num_pizza_given_at_request', hue='requester_received_pizza',  data=df, alpha=0.5)
