# %%
import codecs
import numpy as np
import pandas as pd
import json
import os
import seaborn as sns
import matplotlib.pyplot as plt

def read_dataset(path):
    with codecs.open(path, 'r', 'utf-8') as myFile:
        content = myFile.read()
        dataset = json.loads(content)
    return dataset

# %%
df = pd.read_csv("../data/train_all.csv")

# %% [markdown]
# ## Visualize requester account age

# %%
num_samples = len(df)
num_samples
# Out:
# 3307

# %%
df['requester_account_age_in_days_at_request'].head()
# Out:
# 0    138.781736
# 1    101.809398
# 2    375.025729
# 3    225.675336
# 4    226.049988
# Name: requester_account_age_in_days_at_request, dtype: float64

# %%
plt.figure()
g = sns.catplot(x='requester_received_pizza', y='requester_account_age_in_days_at_request', data=df, alpha=0.3)

plt.xlabel('did the requester receive pizza?')
plt.title("Jurafsky Dataset")
plt.ylabel('requester account age at request (days)')
# Out:
# Text(-2.575000000000003, 0.5, 'requester account age at request (days)')

# %%
colors = {1:'green', 0:'red'}

fig, ax = plt.subplots()
ax.scatter(df['requester_received_pizza'],df['requester_account_age_in_days_at_request'], c=df['requester_received_pizza'].apply(lambda x: colors[x]), alpha=0.5)
ax.set_title('Scatter plot pythonspot.com')
ax.set_xlabel('x')
ax.set_ylabel('y')

fig.show()
# Out:
# /usr/local/Cellar/ipython/7.2.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.
