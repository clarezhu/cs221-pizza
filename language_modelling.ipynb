# %%
import pandas as pd
import pickle

# %%
hm = pd.read_csv("new.csv", sep = "\t")

# %%
hm.head()
# Out:
#    Unnamed: 0                        giver_subreddits_at_request  \
# 0           0            ['LetsNotMeet', 'Random_Acts_Of_Pizza']
# 1           1  ['holdmyfries', 'PetTheDamnKitty', 'SuicideWat...
# 2           2  ['funny', 'politics', 'photography', '2XLookbo...
# 3           3  ['holdmyfries', 'PetTheDamnKitty', 'SuicideWat...
# 4           4            ['LetsNotMeet', 'Random_Acts_Of_Pizza']
#
#    giver_user_flair giver_username  \
# 0               NaN     bobbyshark
# 1               NaN    SanaeKojima
# 2               NaN        shpooey
# 3               NaN    sanaekojima
# 4               NaN     bobbyshark
#
#    number_of_downvotes_of_request_at_retrieval  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
# ...

# %%
dict_list = None
with open('dict_list.pkl','rb') as f:
    dict_list = pickle.load(f)
